# %%
import pandas as pd

# %%
df=pd.read_csv('Advertising.csv')

# %%
df
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   TV          200 non-null    float64
#  2   Radio       200 non-null    float64
#  3   Newspaper   200 non-null    float64
#  4   Sales       200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %%
y=df['Sales']

# %%
x=df[['TV','Radio','Newspaper']]

# %%
print(x)
print(y)
# Out:
#         TV  Radio  Newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# ..     ...    ...        ...
# 195   38.2    3.7       13.8
# 196   94.2    4.9        8.1
# 197  177.0    9.3        6.4
# 198  283.6   42.0       66.2
# 199  232.1    8.6        8.7
#
# [200 rows x 3 columns]
# 0      22.1
# 1      10.4
# 2       9.3
# 3      18.5
# 4      12.9
#        ...
# 195     7.6
# 196     9.7
# 197    12.8
# 198    25.5
# 199    13.4
# Name: Sales, Length: 200, dtype: float64

# %%
print(x.shape)
print(y.shape)
# Out:
# (200, 3)
# (200,)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)

print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (160, 3)
# (40, 3)
# (160,)
# (40,)

# %%
x.columns
# Out:
# Index(['TV', 'Radio', 'Newspaper'], dtype='object')

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
y_pred=lr.predict(x_test)
print(y_pred)
# Out:
# [21.73577184 16.45693776  7.65993185 17.89202679 18.67730671 23.86271904
#  16.33623628 13.45649226  9.177296   17.36056228 14.4677995   9.85697601
#  17.26057027 16.71866935 15.09530285 15.58923732 12.45188167 17.27925151
#  11.0944114  18.06889853  9.33433055 12.91345761  8.7842804  10.46670654
#  11.40303174 15.03104665  9.78479388 19.46028647 18.22954934 17.1958903
#  21.60304218 14.71901407 16.29205532 12.36432281 19.98831261 15.37556411
#  13.96678297 10.06809496 20.97197274  7.45877832]

# %%
a=pd.DataFrame({"Actual":y_test,"Predicted":y_pred})
a
# Out:
#      Actual  Predicted
# 58     23.8  21.735772
# 40     16.6  16.456938
# 34      9.5   7.659932
# 102    14.8  17.892027
# 184    17.6  18.677307
# 198    25.5  23.862719
# 95     16.9  16.336236
# 4      12.9  13.456492
# 29     10.5   9.177296
# 168    17.1  17.360562
# 171    14.5  14.467799
# 18     11.3   9.856976
# 11     17.4  17.260570
# 89     16.7  16.718669
# 110    13.4  15.095303
# 118    15.9  15.589237
# 159    12.9  12.451882
# 35     12.8  17.279252
# 136     9.5  11.094411
# 59     18.4  18.068899
# 51     10.7   9.334331
# 16     12.5  12.913458
# 44      8.5   8.784280
# 94     11.5  10.466707
# 31     11.9  11.403032
# 162    14.9  15.031047
# 38     10.1   9.784794
# 28     18.9  19.460286
# 193    19.6  18.229549
# 27     15.9  17.195890
# 47     23.2  21.603042
# 165    11.9  14.719014
# 194    17.3  16.292055
# 177    11.7  12.364323
# 176    20.2  19.988313
# 97     15.5  15.375564
# 174    11.5  13.966783
# 73     11.0  10.068095
# 69     22.3  20.971973
# ...

# %%
print("Coeff : ",lr.coef_)
print("intercept : ",lr.intercept_)
# Out:
# Coeff :  [0.0468431  0.17854434 0.00258619]
# intercept :  2.9079470208164295

# %%
from sklearn import metrics
print("MAE",metrics.mean_absolute_error(y_test,y_pred))
print("MSE",metrics.mean_squared_error(y_test,y_pred))
print("R2 score",metrics.r2_score(y_test,y_pred))
# Out:
# MAE 1.0402154012924718
# MSE 1.9918855518287906
# R2 score 0.8927605914615384

# %%
d=pd.read_csv('FuelConsumptionCo2.csv')
d.head()
# Out:
#    MODELYEAR   MAKE       MODEL VEHICLECLASS  ENGINESIZE  CYLINDERS  \
# 0       2014  ACURA         ILX      COMPACT         2.0          4
# 1       2014  ACURA         ILX      COMPACT         2.4          4
# 2       2014  ACURA  ILX HYBRID      COMPACT         1.5          4
# 3       2014  ACURA     MDX 4WD  SUV - SMALL         3.5          6
# 4       2014  ACURA     RDX AWD  SUV - SMALL         3.5          6
#
#   TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# 0          AS5        Z                   9.9                  6.7
# 1           M6        Z                  11.2                  7.7
# 2          AV7        Z                   6.0                  5.8
# 3          AS6        Z                  12.7                  9.1
# 4          AS6        Z                  12.1                  8.7
#
#    FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  CO2EMISSIONS
# 0                   8.5                        33           196
# ...

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1067 entries, 0 to 1066
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   MODELYEAR                 1067 non-null   int64
#  1   MAKE                      1067 non-null   object
#  2   MODEL                     1067 non-null   object
#  3   VEHICLECLASS              1067 non-null   object
#  4   ENGINESIZE                1067 non-null   float64
#  5   CYLINDERS                 1067 non-null   int64
#  6   TRANSMISSION              1067 non-null   object
#  7   FUELTYPE                  1067 non-null   object
#  8   FUELCONSUMPTION_CITY      1067 non-null   float64
#  9   FUELCONSUMPTION_HWY       1067 non-null   float64
#  10  FUELCONSUMPTION_COMB      1067 non-null   float64
#  11  FUELCONSUMPTION_COMB_MPG  1067 non-null   int64
#  12  CO2EMISSIONS              1067 non-null   int64
# dtypes: float64(4), int64(4), object(5)
# ...

# %% [markdown]
# - drop : make, model, vehicle class, transmission
# - x : engincesize, cylinders, fuelconsumption_comb
# - model year to age

# %%
d.drop(columns=['MAKE','MODEL','VEHICLECLASS','TRANSMISSION','FUELTYPE'], axis=1, inplace=True)
d.head()
# Out:
#    MODELYEAR  ENGINESIZE  CYLINDERS  FUELCONSUMPTION_CITY  \
# 0       2014         2.0          4                   9.9
# 1       2014         2.4          4                  11.2
# 2       2014         1.5          4                   6.0
# 3       2014         3.5          6                  12.7
# 4       2014         3.5          6                  12.1
#
#    FUELCONSUMPTION_HWY  FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  \
# 0                  6.7                   8.5                        33
# 1                  7.7                   9.6                        29
# 2                  5.8                   5.9                        48
# 3                  9.1                  11.1                        25
# 4                  8.7                  10.6                        27
#
#    CO2EMISSIONS
# 0           196
# 1           221
# 2           136
# 3           255
# 4           244

# %%
d['AGE']=2026-d['MODELYEAR']
d.drop('MODELYEAR', axis=1, inplace=True)
d
# Out:
#       ENGINESIZE  CYLINDERS  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# 0            2.0          4                   9.9                  6.7
# 1            2.4          4                  11.2                  7.7
# 2            1.5          4                   6.0                  5.8
# 3            3.5          6                  12.7                  9.1
# 4            3.5          6                  12.1                  8.7
# ...          ...        ...                   ...                  ...
# 1062         3.0          6                  13.4                  9.8
# 1063         3.2          6                  13.2                  9.5
# 1064         3.0          6                  13.4                  9.8
# 1065         3.2          6                  12.9                  9.3
# 1066         3.2          6                  14.9                 10.2
#
#       FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  CO2EMISSIONS  AGE
# ...

# %%
y=d['CO2EMISSIONS']
x=d[['ENGINESIZE','CYLINDERS','FUELCONSUMPTION_COMB']]

# %%
print(x.shape)
print(y.shape)
# Out:
# (1067, 3)
# (1067,)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)

print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (853, 3)
# (214, 3)
# (853,)
# (214,)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
y_pred=lr.predict(x_test)
print(y_pred)
# Out:
# [257.0729753  193.62675365 198.61947156 184.0315625  308.84886971
#  222.06199356 185.00408977 193.38929893 234.70484808 197.40948958
#  217.83256226 260.96308439 200.32707139 363.64971908 200.51083953
#  192.73062136 193.99428993 314.31649706 261.88192508 215.88750772
#  440.76775066 216.07127586 254.46924319 258.96434327 279.75495223
#  239.56748443 162.03372438 288.13465573 187.18659903 231.68539877
#  229.84221172 367.53982816 246.32148875 360.70666476 285.37813365
#  315.9704103  351.66277803 181.16766727 341.17972436 257.62427972
#  239.56748443 373.66062742 215.15243517 257.20305686 256.41429773
#  201.53705338 189.73664457 161.53335371 181.11398069 250.02782969
#  189.13165357 336.15602827 329.4839246  344.85508713 211.26232608
#  269.05715225 208.29105769 289.16086958 263.22198863 185.24154449
#  209.07981683 238.80693936 209.31727154 194.72936248 215.15243517
#  193.38929893 259.33187954 253.31294778 204.45463519 209.55472626
# ...

# %%
a=pd.DataFrame({"Actual":y_test,"Predicted":y_pred})
a
# Out:
#      Actual   Predicted
# 133     274  257.072975
# 340     200  193.626754
# 948     196  198.619472
# 704     161  184.031563
# 661     320  308.848870
# ..      ...         ...
# 961     301  275.681075
# 523     184  189.131654
# 884     274  266.323339
# 8       267  262.249461
# 415     126  169.443653
#
# [214 rows x 2 columns]

# %%
print("Coeff : ",lr.coef_)
print("intercept : ",lr.intercept_)
# Out:
# Coeff :  [11.56295409  6.91231122  9.72527271]
# intercept :  65.17950048137254

# %%
from sklearn import metrics
print("MAE",metrics.mean_absolute_error(y_test,y_pred))
print("MSE",metrics.mean_squared_error(y_test,y_pred))
print("R2 score",metrics.r2_score(y_test,y_pred))  # COEFFICIENT OF DETERMINATION=R2
# Out:
# MAE 16.64682799882323
# MSE 546.2591396903438
# R2 score 0.8653355812644816

# %% [markdown]
# ## POLY LINEAR REGRESSION

# %%
df=pd.read_csv('polylinearregression.csv')
df
# Out:
#    sno  Temperature  Pressure
# 0    1            0    0.0002
# 1    2           20    0.0012
# 2    3           40    0.0060
# 3    4           60    0.0300
# 4    5           80    0.0900
# 5    6          100    0.2700

# %%
x=df[['Temperature']]
y=df['Pressure']

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x,y)
y_pred=lr.predict(x)
print(y_pred)
# Out:
# [-0.05086667 -0.00402667  0.04281333  0.08965333  0.13649333  0.18333333]

# %%
from sklearn.metrics import r2_score
print("R2 score : ",r2_score(y,y_pred))
# Out:
# R2 score :  0.690349972603981

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(4,4))
plt.scatter(x,y,color="blue")
plt.plot(x,y_pred,color='red')
plt.show()

# %%
df=pd.read_csv('car_data.csv')
df
# Out:
#    Horsepower  Weight  MPG
# 0         130    3504   18
# 1         165    3693   15
# 2         150    3436   18
# 3         140    3433   16
# 4         198    4341   14
# 5         220    4354   12
# 6          95    2372   25
# 7          88    2130   27
# 8          98    2228   24

# %%
df.columns
# Out:
# Index(['Horsepower', 'Weight', 'MPG'], dtype='object')

# %%
x=df[['Horsepower', 'Weight']]
y=df['MPG']

# %%
print(x.shape)
print(y.shape)
# Out:
# (9, 2)
# (9,)

# %%
from sklearn.preprocessing import PolynomialFeatures
poly=PolynomialFeatures(degree=2)
x_poly=poly.fit_transform(x)
print(x_poly)
# Out:
# [[1.0000000e+00 1.3000000e+02 3.5040000e+03 1.6900000e+04 4.5552000e+05
#   1.2278016e+07]
#  [1.0000000e+00 1.6500000e+02 3.6930000e+03 2.7225000e+04 6.0934500e+05
#   1.3638249e+07]
#  [1.0000000e+00 1.5000000e+02 3.4360000e+03 2.2500000e+04 5.1540000e+05
#   1.1806096e+07]
#  [1.0000000e+00 1.4000000e+02 3.4330000e+03 1.9600000e+04 4.8062000e+05
#   1.1785489e+07]
#  [1.0000000e+00 1.9800000e+02 4.3410000e+03 3.9204000e+04 8.5951800e+05
#   1.8844281e+07]
#  [1.0000000e+00 2.2000000e+02 4.3540000e+03 4.8400000e+04 9.5788000e+05
#   1.8957316e+07]
#  [1.0000000e+00 9.5000000e+01 2.3720000e+03 9.0250000e+03 2.2534000e+05
#   5.6263840e+06]
#  [1.0000000e+00 8.8000000e+01 2.1300000e+03 7.7440000e+03 1.8744000e+05
#   4.5369000e+06]
#  [1.0000000e+00 9.8000000e+01 2.2280000e+03 9.6040000e+03 2.1834400e+05
#   4.9639840e+06]]

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(x_poly,y,test_size=0.2,random_state=1)  # random_state is used for getting accurate value of train,test

print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (7, 6)
# (7,)
# (2, 6)
# (2,)

# %%
from sklearn.linear_model import LinearRegression

lr=LinearRegression()
lr.fit(x_train,y_train)
y_pred=lr.predict(x_test)

# %%
from sklearn.metrics import r2_score
print("R2 score : ",r2_score(y_test,y_pred))
# Out:
# R2 score :  0.5889966459548845

# %% [markdown]
# multiple

# %%
df=pd.read_csv('car_data.csv')

# %%
x=df[['Horsepower', 'Weight']]
y=df['MPG']
print(x.shape)
print(y.shape)
# Out:
# (9, 2)
# (9,)

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)  # random_state is used for getting accurate value of train,test

print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (7, 2)
# (7,)
# (2, 2)
# (2,)

# %%
from sklearn.linear_model import LinearRegression

lr=LinearRegression()
lr.fit(x_train,y_train)
y_pred=lr.predict(x_test)
print(y_pred)
# Out:
# [25.75164901 17.94017483]

# %%
from sklearn import metrics
print("R2 score : ",metrics.r2_score(y_test,y_pred))
# Out:
# R2 score :  0.8293414835733268

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression
import pandas as pd

x=[1,2,3,4,5]
y=[1,8,27,64,125]

x=pd.DataFrame(x)
y=pd.DataFrame(y)

poly=PolynomialFeatures(degree=2)
x_poly=poly.fit_transform(x)

model=LinearRegression()
model.fit(x_poly,y)
y_pred=model.predict(x_poly)

print("R2 Score : ",r2_score(y,y_pred))
# Out:
# R2 Score :  0.998614051973051

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression
import pandas as pd

x=[1,2,3,4,5]
y=[1,8,27,64,125]

x=pd.DataFrame(x)
y=pd.DataFrame(y)

poly=PolynomialFeatures(degree=3)
x_poly=poly.fit_transform(x)

model=LinearRegression()
model.fit(x_poly,y)
y_pred=model.predict(x_poly)

print("R2 Score : ",r2_score(y,y_pred))
# Out:
# R2 Score :  1.0
